# %% [markdown]
# <a href="https://colab.research.google.com/github/adc257/AmEx-Project/blob/Aaron_branch/Playing_with_the_SoftMax_Layer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Introduction
# The paper *A Baseline for Detecting Misclassified and Out-of-Distribution Examples in Neural Networks* suggests that using **softmax layer** to detect the mislabeled item.
#
# This method relies on the observation that *correctly labeled examples tends to **have higher softmax probabilities**.*
#
# Therefore, **setting a proper threshold** for the softmax layer's output can help us detect the mislabeled items.

# %% [markdown]
# I would use `BERT-Banking77` on the `banking77` dataset to show how this method can be performed.

# %% [markdown]
# ## 2. Testing
# ### Step1: Loading the Model, Tokenizer, and Dataset

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from datasets import load_dataset
import torch
from torch.nn.functional import softmax

# Load the tokenizer, model, and dataset
tokenizer = AutoTokenizer.from_pretrained("philschmid/BERT-Banking77")
model = AutoModelForSequenceClassification.from_pretrained("philschmid/BERT-Banking77")
dataset = load_dataset("banking77")

# %% [markdown]
# ### Step2: Process the dataset and perform prediction

# %%
# For simplicity, I just use a piece of the dataset
test_dataset = dataset['test'].select(range(666))  # Lucky number

# Tokenize the test-set
inputs = tokenizer(test_dataset['text'], padding=True, truncation=True, return_tensors="pt")

# Predict categories (This maybe slow 2mins: keep waiting cuz the model is performing prediction :))
with torch.no_grad():
    logits = model(**inputs).logits

# %% [markdown]
# ### Step3: Set a threshold value and calculate the softmax probabilities

# %%
# Calculate and convert them to tensor
probabilities = softmax(logits, dim=1)
max_probabilities, predictions = torch.max(probabilities, dim=1)

label_ids = torch.tensor(test_dataset['label'])

# Set threshold (I personally think that 0.9 would be a good value)
threshold = 0.9

# %% [markdown]
# ### Step4: Finding the mismatching item

# %%
# If the labels and the predictions don't fit well
mismatches = predictions != label_ids

for i, (mismatch, max_prob) in enumerate(zip(mismatches, max_probabilities)):
    if mismatch and max_prob < threshold:
        # Flagging items that are potential mislabels and have low confidence in prediction
        predicted_label_name = model.config.id2label[predictions[i].item()]
        actual_label_name = model.config.id2label[label_ids[i].item()]  # Using label_ids directly for mapping

        print(f"Potential mislabel detected at index {i}: '{test_dataset['text'][i]}'")
        print(f"Predicted Label: '{predicted_label_name}' with probability {max_prob.item()}")
        print(f"Original Label: '{actual_label_name}'\n")
# Out:
# Potential mislabel detected at index 0: 'How do I locate my card?'
# Predicted: 'card_arrival' with probability 0.46647942066192627
# Actual: 'card_acceptance'
#
# Potential mislabel detected at index 21: 'Status of the card I ordered.'
# Predicted: 'lost_or_stolen_card' with probability 0.37437352538108826
# Actual: 'card_acceptance'
#
# Potential mislabel detected at index 36: 'I'm starting to think my card is lost because it still hasn't arrived, can you help?'
# Predicted: 'card_arrival' with probability 0.7686095237731934
# Actual: 'card_acceptance'
#
# Potential mislabel detected at index 37: 'Is there tracking info available?'
# Predicted: 'card_arrival' with probability 0.6687702536582947
# Actual: 'card_acceptance'
#
# Potential mislabel detected at index 60: 'How do I link to my credit card with you?'
# Predicted: 'card_linking' with probability 0.8874982595443726
# Actual: 'card_delivery_estimate'
#
# Potential mislabel detected at index 66: 'The app doesn't show the card I received.'
# Predicted: 'card_linking' with probability 0.5351898670196533
# Actual: 'card_delivery_estimate'
#
# Potential mislabel detected at index 93: 'Is it a good time to exchange?'
# Predicted: 'exchange_via_app' with probability 0.8883020877838135
# Actual: 'exchange_charge'
#
# Potential mislabel detected at index 97: 'Will I get a curreng foreign exchange rate?'
# Predicted: 'exchange_rate' with probability 0.7526914477348328
# Actual: 'exchange_charge'
#
# Potential mislabel detected at index 105: 'How much will I get with the exchange rate?'
# Predicted: 'exchange_rate' with probability 0.7479652166366577
# Actual: 'exchange_charge'
#
# Potential mislabel detected at index 115: 'why do your exchange rates change'
# Predicted: 'exchange_rate' with probability 0.8027769327163696
# Actual: 'exchange_charge'
#
# Potential mislabel detected at index 125: 'This rate is too low. Are you sure your using the right exchange rate.'
# Predicted: 'card_payment_wrong_exchange_rate' with probability 0.5660334825515747
# Actual: 'card_payment_not_recognised'
#
# Potential mislabel detected at index 136: 'The exchange rate for my transaction last Saturday seems to have been wrong I got charged extra.  Please fix.'
# Predicted: 'card_payment_wrong_exchange_rate' with probability 0.8635843396186829
# Actual: 'card_payment_not_recognised'
#
# Potential mislabel detected at index 145: 'The exchange rate seems off on this transaction'
# Predicted: 'card_payment_wrong_exchange_rate' with probability 0.5154232382774353
# Actual: 'card_payment_not_recognised'
#
# Potential mislabel detected at index 147: 'Hi, I don't think your exchange rate is right. I need you to check the official interbank exchange please.'
# Predicted: 'card_payment_wrong_exchange_rate' with probability 0.892874538898468
# Actual: 'card_payment_not_recognised'
#
# Potential mislabel detected at index 150: 'the conversion value for my card payments is incorrect.'
# Predicted: 'card_payment_wrong_exchange_rate' with probability 0.6164072751998901
# Actual: 'card_payment_not_recognised'
#
# Potential mislabel detected at index 156: 'How can I check the exchange rate applied to my transaction?'
# Predicted: 'exchange_rate' with probability 0.3576214909553528
# Actual: 'card_payment_not_recognised'
#
# Potential mislabel detected at index 164: 'There is a fee I don't recognize on my statement.'
# Predicted: 'extra_charge_on_statement' with probability 0.7495355606079102
# Actual: 'exchange_via_app'
#
# Potential mislabel detected at index 168: 'Why does my statement have these extra charges?'
# Predicted: 'extra_charge_on_statement' with probability 0.8991472721099854
# Actual: 'exchange_via_app'
#
# Potential mislabel detected at index 178: 'Why are there so many fees on my statement?'
# Predicted: 'card_payment_fee_charged' with probability 0.4690854251384735
# Actual: 'exchange_via_app'
#
# Potential mislabel detected at index 180: 'Where did this 1 euro fee come from?'
# Predicted: 'extra_charge_on_statement' with probability 0.890400767326355
# Actual: 'exchange_via_app'
#
# Potential mislabel detected at index 189: 'I am a new customer, and I happened to look at my app and there is a charge I am not familiar with.  Could you tell me why the extra charge is there?'
# Predicted: 'transfer_fee_charged' with probability 0.3959408104419708
# Actual: 'exchange_via_app'
#
# Potential mislabel detected at index 193: 'What is the purpose of the extra fee that is showing up on my statement?'
# Predicted: 'extra_charge_on_statement' with probability 0.8302767276763916
# Actual: 'exchange_via_app'
#
# Potential mislabel detected at index 199: 'Can you please check why I am having this extra fee on my statement.'
# Predicted: 'extra_charge_on_statement' with probability 0.8574455976486206
# Actual: 'exchange_via_app'
#
# Potential mislabel detected at index 235: 'Where's accounting for my cash withdrawal?'
# Predicted: 'pending_cash_withdrawal' with probability 0.7394037246704102
# Actual: 'pending_card_payment'
#
# Potential mislabel detected at index 237: 'how long does it take to post atm with drawl'
# Predicted: 'pending_cash_withdrawal' with probability 0.808167040348053
# Actual: 'pending_card_payment'
#
# Potential mislabel detected at index 240: 'If I request that my funds be held, what currencies do you use?'
# Predicted: 'fiat_currency_support' with probability 0.7952666878700256
# Actual: 'failed_transfer'
#
# Potential mislabel detected at index 243: 'Does your system support multiple currency.'
# Predicted: 'fiat_currency_support' with probability 0.4375997483730316
# Actual: 'failed_transfer'
#
# Potential mislabel detected at index 254: 'Do you offer additional currency options?'
# Predicted: 'fiat_currency_support' with probability 0.5569210052490234
# Actual: 'failed_transfer'
#
# Potential mislabel detected at index 268: 'I want to make a currency exchange to EU.'
# Predicted: 'fiat_currency_support' with probability 0.766779899597168
# Actual: 'failed_transfer'
#
# Potential mislabel detected at index 280: 'I need my card now!'
# Predicted: 'card_delivery_estimate' with probability 0.7461872100830078
# Actual: 'card_arrival'
#
# Potential mislabel detected at index 291: 'How long will it take to arrive?'
# Predicted: 'card_delivery_estimate' with probability 0.8670675754547119
# Actual: 'card_arrival'
#
# Potential mislabel detected at index 299: 'How long will it take for the card to arrive?'
# Predicted: 'card_delivery_estimate' with probability 0.771479606628418
# Actual: 'card_arrival'
#
# Potential mislabel detected at index 301: 'Ordered awhile back, what is the ETA in the US?'
# Predicted: 'fiat_currency_support' with probability 0.30008605122566223
# Actual: 'card_arrival'
#
# Potential mislabel detected at index 339: 'How do I make sure I don't run out of money on my card while traveling?'
# Predicted: 'wrong_exchange_rate_for_cash_withdrawal' with probability 0.48290926218032837
# Actual: 'atm_support'
#
# Potential mislabel detected at index 345: 'Can I space out how often money is transferred along my travels?'
# Predicted: 'balance_not_updated_after_bank_transfer' with probability 0.28899267315864563
# Actual: 'atm_support'
#
# Potential mislabel detected at index 357: 'Is there a top-up feature, if there isn't a lot of money left?'
# Predicted: 'pending_top_up' with probability 0.7524839639663696
# Actual: 'atm_support'
#
# Potential mislabel detected at index 360: 'I've tried my card a bunch of times and it never worked.'
# Predicted: 'card_not_working' with probability 0.8025839328765869
# Actual: 'card_linking'
#
# Potential mislabel detected at index 382: 'I broke my card'
# Predicted: 'card_not_working' with probability 0.895343542098999
# Actual: 'card_linking'
#
# Potential mislabel detected at index 397: 'Nothing goes through on my card.'
# Predicted: 'declined_card_payment' with probability 0.44419384002685547
# Actual: 'card_linking'
#
# Potential mislabel detected at index 416: 'How would I use my money in a different country?'
# Predicted: 'receiving_money' with probability 0.5607374310493469
# Actual: 'exchange_rate'
#
# Potential mislabel detected at index 428: 'What currency's can i exchange for?'
# Predicted: 'fiat_currency_support' with probability 0.5170364379882812
# Actual: 'exchange_rate'
#
# Potential mislabel detected at index 440: 'My entire gym bag, including my wallet, was stolen out of my locker today. Everything in my wallet is gone - how do I block the card to make it can't be used?'
# Predicted: 'lost_or_stolen_card' with probability 0.7400619387626648
# Actual: 'getting_virtual_card'
#
# Potential mislabel detected at index 453: 'Is a copy of the police report necessary for completing the report process?'
# Predicted: 'verify_my_identity' with probability 0.6222618818283081
# Actual: 'getting_virtual_card'
#
# Potential mislabel detected at index 454: 'I lost my wallet today with all my credit cards. Will you please block the card and send a replacement?'
# Predicted: 'lost_or_stolen_card' with probability 0.7053282260894775
# Actual: 'getting_virtual_card'
#
# Potential mislabel detected at index 459: 'I need help with a lost card'
# Predicted: 'lost_or_stolen_card' with probability 0.8373640179634094
# Actual: 'getting_virtual_card'
#
# Potential mislabel detected at index 467: 'My card was taken from me'
# Predicted: 'lost_or_stolen_card' with probability 0.8298054933547974
# Actual: 'getting_virtual_card'
#
# Potential mislabel detected at index 473: 'I believe my credit card was stolen.'
# Predicted: 'lost_or_stolen_card' with probability 0.6946842670440674
# Actual: 'getting_virtual_card'
#
# Potential mislabel detected at index 475: 'Somebody has stolen my card, I need help please.'
# Predicted: 'lost_or_stolen_card' with probability 0.8553194403648376
# Actual: 'getting_virtual_card'
#
# Potential mislabel detected at index 476: 'I cannot find my credit card.'
# Predicted: 'topping_up_by_card' with probability 0.41628772020339966
# Actual: 'getting_virtual_card'
#
# Potential mislabel detected at index 477: 'Are you able to locate my card?'
# Predicted: 'lost_or_stolen_card' with probability 0.7600128650665283
# Actual: 'getting_virtual_card'
#
# Potential mislabel detected at index 522: 'Will you reinstate my PIN?'
# Predicted: 'change_pin' with probability 0.7847080826759338
# Actual: 'pending_transfer'
#
# Potential mislabel detected at index 537: 'I attempted to use my card while I was intoxicated, and I failed to input my PIN, and the machine kept my card. How soon can I have it back?'
# Predicted: 'pin_blocked' with probability 0.36699342727661133
# Actual: 'pending_transfer'
#
# Potential mislabel detected at index 542: 'My account is blocked, how do I log in now'
# Predicted: 'terminate_account' with probability 0.6324453353881836
# Actual: 'pending_transfer'
#
# Potential mislabel detected at index 551: 'Can I reactivate my PIN?'
# Predicted: 'change_pin' with probability 0.5767920017242432
# Actual: 'pending_transfer'
#
# Potential mislabel detected at index 558: 'My PIN is not working and I need assistance.'
# Predicted: 'pin_blocked' with probability 0.8745925426483154
# Actual: 'pending_transfer'
#
# Potential mislabel detected at index 560: 'Are contactless payments enabled on my new card?'
# Predicted: 'contactless_not_working' with probability 0.8898800015449524
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 561: 'My contanctless has stopped working'
# Predicted: 'card_not_working' with probability 0.5494968295097351
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 562: 'what is required documents for new card process ?'
# Predicted: 'contactless_not_working' with probability 0.47283077239990234
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 563: 'I don't know what's wrong, my contactless stopped working. Tried it in a few different places today and it didn't work in any of them.'
# Predicted: 'contactless_not_working' with probability 0.897354781627655
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 564: 'How do I get the contactless feature to work for my card?'
# Predicted: 'contactless_not_working' with probability 0.8937422037124634
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 571: 'I couldn't use my contactless this morning, it wasn't accepted.'
# Predicted: 'contactless_not_working' with probability 0.8973090648651123
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 573: 'Why wouldn't the contactless payment work when I tried to pay at the bus today?'
# Predicted: 'contactless_not_working' with probability 0.899750828742981
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 574: 'How do I check my security settings to allow contactless pay?'
# Predicted: 'contactless_not_working' with probability 0.8927231431007385
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 576: 'Fix my contactless'
# Predicted: 'contactless_not_working' with probability 0.8973749279975891
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 577: 'How can I make my contactless work for the metro?'
# Predicted: 'contactless_not_working' with probability 0.8996743559837341
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 579: 'Can you help my fix my contactless?'
# Predicted: 'contactless_not_working' with probability 0.8991798758506775
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 581: 'I'm unable to use contactless payments for purchases.'
# Predicted: 'contactless_not_working' with probability 0.8957563042640686
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 582: 'When I tried to pay for my bus ride, the contactless payment wouldn't work. How can I prevent this in the future?'
# Predicted: 'contactless_not_working' with probability 0.8985735177993774
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 583: 'The NFC payment wouldn't work on the bus today. Help?'
# Predicted: 'declined_card_payment' with probability 0.26703524589538574
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 585: 'How do I make contactless work'
# Predicted: 'contactless_not_working' with probability 0.8984692096710205
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 586: 'what is the charges for new card?'
# Predicted: 'contactless_not_working' with probability 0.7644278407096863
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 592: 'How do I use contactless payments?'
# Predicted: 'contactless_not_working' with probability 0.8967583179473877
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 595: 'How do I use contactless pay?'
# Predicted: 'contactless_not_working' with probability 0.8860098123550415
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 596: 'How do I enable contactless pay?'
# Predicted: 'contactless_not_working' with probability 0.8858889937400818
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 597: 'Do I need to make a regular payment before a contactless one?'
# Predicted: 'contactless_not_working' with probability 0.894858717918396
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 598: 'How can I find out where my contactless works?'
# Predicted: 'contactless_not_working' with probability 0.8973171710968018
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 599: 'Should i reinstall the payment app?'
# Predicted: 'contactless_not_working' with probability 0.6656307578086853
# Actual: 'compromised_card'
#
# Potential mislabel detected at index 602: 'I need to make a transfer, what will the fee be?'
# Predicted: 'transfer_fee_charged' with probability 0.6470018029212952
# Actual: 'top_up_by_bank_transfer_charge'
#
# Potential mislabel detected at index 606: 'I would like to refill my account using SWIFT.'
# Predicted: 'top_up_by_cash_or_cheque' with probability 0.7399324774742126
# Actual: 'top_up_by_bank_transfer_charge'
#
# Potential mislabel detected at index 641: 'My card was topped this morning but I can't see the funds. Why didn't it complete?'
# Predicted: 'pending_top_up' with probability 0.6689407229423523
# Actual: 'pending_cash_withdrawal'
#
# Potential mislabel detected at index 647: 'I've already topped up, but I cannot see the funds being available. What happened?'
# Predicted: 'top_up_reverted' with probability 0.8841702938079834
# Actual: 'pending_cash_withdrawal'
#
# Potential mislabel detected at index 649: 'I  do not see a top-up processed.'
# Predicted: 'pending_top_up' with probability 0.8740442395210266
# Actual: 'pending_cash_withdrawal'
#
# Potential mislabel detected at index 657: 'top-up is slow to process'
# Predicted: 'pending_top_up' with probability 0.8954901695251465
# Actual: 'pending_cash_withdrawal'
#
# Potential mislabel detected at index 661: 'top up did not complete'
# Predicted: 'pending_top_up' with probability 0.7426334619522095
# Actual: 'pending_cash_withdrawal'
#
# Potential mislabel detected at index 662: 'So I just put my top-up into the card and it hasn't changed.'
# Predicted: 'pending_top_up' with probability 0.6682242751121521
# Actual: 'pending_cash_withdrawal'

# %% [markdown]
# ## 3. Conclusion
# We can checking the phenomenace of **Higher Softmax Probability on an Incorrect Prediction**, which could hint **potential mislabeling** in the dataset.
#
# For example:
# ```
# Potential mislabel detected at index 180: 'Where did this 1 euro fee come from?'
# Predicted: 'extra_charge_on_statement' with probability 0.890400767326355
# Actual: 'exchange_via_app'
#
# Potential mislabel detected at index 573: 'Why wouldn't the contactless payment work when I tried to pay at the bus today?'
# Predicted: 'contactless_not_working' with probability 0.899750828742981
# Actual: 'compromised_card'
# ```
# We can then change it manually or using the code to change the mislabeled items.
