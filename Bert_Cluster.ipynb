# %%
# !pip install hdbscan
# !pip install sentence-transformers
# !pip install umap-learn
# Out:
# Collecting hdbscan
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 35.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cython<3,>=0.27 (from hdbscan)
#   Using cached Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.25.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.2.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20->hdbscan) (3.3.0)
# Building wheels for collected packages: hdbscan
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039295 sha256=ef4b34c99b2e3b8a7deaeadabd1628bd11e4e70373ecd5343bfcf16082d3be68
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
# Successfully built hdbscan
# Installing collected packages: cython, hdbscan
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.9
#     Uninstalling Cython-3.0.9:
#       Successfully uninstalled Cython-3.0.9
# Successfully installed cython-0.29.37 hdbscan-0.8.33
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.5.1-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.38.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.1.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.5.1
# Collecting umap-learn
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.41.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.3.0)
# Building wheels for collected packages: umap-learn
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=725a4b9fcf0490ff2daa9e10119e6b4a7960d952f09c0d0988c5213541123b79
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
# Successfully built umap-learn
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.11 umap-learn-0.5.5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize
from sklearn.preprocessing import Normalizer

from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

from hdbscan import HDBSCAN
from sklearn import metrics


from sentence_transformers import SentenceTransformer
import umap

# %%
import warnings
warnings.filterwarnings("ignore")

import os

# %%
from transformers import BertTokenizer, BertModel

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

train_test = pd.concat([train, test], ignore_index=True)

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# %%
def get_sentence_embeddings(sentence):
    inputs = tokenizer(sentence, return_tensors="pt", truncation=True, max_length=512)
    outputs = model(**inputs)
    embeddings = outputs.last_hidden_state.mean(dim=1).squeeze().detach().numpy()
    return embeddings

# Apply the function to each utterance
test['BERT_embeddings'] = test['text'].apply(get_sentence_embeddings)
test
# Out:
#                                                    text         category  \
# 0                              How do I locate my card?     card_arrival
# 1     I still have not received my new card, I order...     card_arrival
# 2     I ordered a card but it has not arrived. Help ...     card_arrival
# 3      Is there a way to know when my card will arrive?     card_arrival
# 4                          My card has not arrived yet.     card_arrival
# ...                                                 ...              ...
# 3075      If i'm not in the UK, can I still get a card?  country_support
# 3076                 How many countries do you support?  country_support
# 3077              What countries do you do business in?  country_support
# 3078             What are the countries you operate in.  country_support
# 3079         Can the card be mailed and used in Europe?  country_support
#
#                                         BERT_embeddings
# 0     [0.11946714, 0.0462514, 0.07216076, -0.0717430...
# 1     [0.1455653, -0.17301682, 0.396418, 0.20625193,...
# 2     [-0.050330862, -0.2557014, 0.44595417, -0.0304...
# 3     [-0.044740878, -0.3670077, 0.41925043, 0.03467...
# 4     [0.3028919, -0.22428086, 0.10192727, -0.203572...
# ...                                                 ...
# 3075  [0.49874625, -0.046890993, 0.43037665, -0.3773...
# 3076  [0.4169197, -0.19576609, 0.10278029, -0.101284...
# 3077  [0.43335438, -0.14970121, -0.07299802, -0.2744...
# 3078  [0.26136342, -0.20304756, -0.15264143, -0.1744...
# 3079  [0.21379073, -0.5117322, 0.2260205, 0.19019113...
#
# [3080 rows x 3 columns]

# %%
bert_embeddings = np.vstack(test['BERT_embeddings'].to_numpy())

umap_embeddings = umap.UMAP(n_neighbors=10, n_components=5, metric='cosine').fit_transform(bert_embeddings)

# %%
hdbscan = HDBSCAN(min_cluster_size=18)
test["topic"] = hdbscan.fit_predict(umap_embeddings)
test
# Out:
#                                                    text         category  \
# 0                              How do I locate my card?     card_arrival
# 1     I still have not received my new card, I order...     card_arrival
# 2     I ordered a card but it has not arrived. Help ...     card_arrival
# 3      Is there a way to know when my card will arrive?     card_arrival
# 4                          My card has not arrived yet.     card_arrival
# ...                                                 ...              ...
# 3075      If i'm not in the UK, can I still get a card?  country_support
# 3076                 How many countries do you support?  country_support
# 3077              What countries do you do business in?  country_support
# 3078             What are the countries you operate in.  country_support
# 3079         Can the card be mailed and used in Europe?  country_support
#
#                                         BERT_embeddings  topic
# 0     [0.11946714, 0.0462514, 0.07216076, -0.0717430...     11
# 1     [0.1455653, -0.17301682, 0.396418, 0.20625193,...     -1
# 2     [-0.050330862, -0.2557014, 0.44595417, -0.0304...     -1
# 3     [-0.044740878, -0.3670077, 0.41925043, 0.03467...     -1
# 4     [0.3028919, -0.22428086, 0.10192727, -0.203572...     -1
# ...                                                 ...    ...
# 3075  [0.49874625, -0.046890993, 0.43037665, -0.3773...     10
# 3076  [0.4169197, -0.19576609, 0.10278029, -0.101284...     11
# 3077  [0.43335438, -0.14970121, -0.07299802, -0.2744...     11
# 3078  [0.26136342, -0.20304756, -0.15264143, -0.1744...     -1
# 3079  [0.21379073, -0.5117322, 0.2260205, 0.19019113...     -1
#
# [3080 rows x 4 columns]

# %%
custom_colors = [
    '#000000', '#33FF57', '#5733FF', '#FFFF33', '#33FFFF',
    '#FF3366', '#66FF33', '#FFCC33', '#CC33FF',
    '#FF6633', '#33FFCC', '#9933FF', '#FF33CC', '#66CCFF',
    '#FF9933', '#33FF99', '#9966FF', '#FF66CC', '#66FF66',
    '#FF6666', '#66CC66', '#CC66FF', '#FF9966', '#66FFCC', '#FFCC66'
]
custom_palette = sns.color_palette(custom_colors)

plt.figure(figsize=(10, 8))
sns.scatterplot(x=umap_embeddings[:, 0], y=umap_embeddings[:, 1], hue=test["topic"], legend='full', alpha=0.8, palette=custom_palette)
plt.title('HDBSCAN Clustering')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.legend()
plt.show()

# %%
cluster_info = {}
for i in np.unique(hdbscan.labels_):
  rah = test[test["topic"]== i]
  value_counts = rah["category"].value_counts()

  category_info = {}
  for index, count in value_counts.items():
    category_info[index] = count

  cluster_info[i] = category_info

cluster_info
# Out:
# {-1: {'lost_or_stolen_phone': 33,
#   'request_refund': 29,
#   'card_arrival': 28,
#   'beneficiary_not_allowed': 25,
#   'declined_card_payment': 24,
#   'lost_or_stolen_card': 23,
#   'card_swallowed': 22,
#   'activate_my_card': 21,
#   'card_payment_not_recognised': 21,
#   'card_delivery_estimate': 20,
#   'declined_cash_withdrawal': 20,
#   'wrong_amount_of_cash_received': 20,
#   'Refund_not_showing_up': 19,
#   'why_verify_identity': 18,
#   'cash_withdrawal_not_recognised': 18,
#   'contactless_not_working': 18,
#   'topping_up_by_card': 18,
#   'declined_transfer': 17,
#   'transaction_charged_twice': 17,
#   'cancel_transfer': 17,
#   'reverted_card_payment?': 16,
#   'transfer_not_received_by_recipient': 16,
#   'transfer_into_account': 15,
#   'card_not_working': 15,
#   'top_up_failed': 15,
#   'pending_card_payment': 15,
#   'extra_charge_on_statement': 15,
#   'top_up_reverted': 14,
#   'passcode_forgotten': 14,
#   'failed_transfer': 12,
#   'balance_not_updated_after_bank_transfer': 12,
#   'verify_my_identity': 12,
#   'direct_debit_payment_not_recognised': 12,
#   'balance_not_updated_after_cheque_or_cash_deposit': 12,
#   'pending_transfer': 11,
#   'verify_top_up': 11,
#   'card_linking': 11,
#   'get_physical_card': 11,
#   'exchange_via_app': 11,
#   'automatic_top_up': 11,
#   'transfer_fee_charged': 11,
#   'pending_top_up': 11,
#   'pin_blocked': 10,
#   'pending_cash_withdrawal': 10,
#   'apple_pay_or_google_pay': 10,
#   'getting_spare_card': 9,
#   'order_physical_card': 9,
#   'card_payment_fee_charged': 9,
#   'cash_withdrawal_charge': 8,
#   'change_pin': 8,
#   'top_up_by_bank_transfer_charge': 7,
#   'edit_personal_details': 7,
#   'unable_to_verify_identity': 7,
#   'compromised_card': 7,
#   'exchange_rate': 6,
#   'card_acceptance': 6,
#   'supported_cards_and_currencies': 5,
#   'card_payment_wrong_exchange_rate': 5,
#   'atm_support': 5,
#   'card_about_to_expire': 5,
#   'virtual_card_not_working': 4,
#   'fiat_currency_support': 4,
#   'wrong_exchange_rate_for_cash_withdrawal': 4,
#   'country_support': 4,
#   'exchange_charge': 3,
#   'top_up_by_cash_or_cheque': 2,
#   'top_up_limits': 2,
#   'terminate_account': 2,
#   'getting_virtual_card': 2,
#   'visa_or_mastercard': 2,
#   'age_limit': 1,
#   'receiving_money': 1,
#   'disposable_card_limits': 1,
#   'transfer_timing': 1,
#   'verify_source_of_funds': 1},
#  0: {'disposable_card_limits': 36,
#   'get_disposable_virtual_card': 34,
#   'virtual_card_not_working': 20,
#   'contactless_not_working': 1,
#   'top_up_limits': 1,
#   'getting_spare_card': 1,
#   'cash_withdrawal_charge': 1},
#  1: {'age_limit': 35},
#  2: {'transfer_timing': 38,
#   'card_delivery_estimate': 14,
#   'pending_transfer': 11,
#   'balance_not_updated_after_bank_transfer': 7,
#   'transfer_not_received_by_recipient': 5,
#   'pending_card_payment': 5,
#   'pending_cash_withdrawal': 4,
#   'card_arrival': 3,
#   'balance_not_updated_after_cheque_or_cash_deposit': 2,
#   'Refund_not_showing_up': 2,
#   'extra_charge_on_statement': 1,
#   'pending_top_up': 1,
#   'unable_to_verify_identity': 1,
#   'activate_my_card': 1,
#   'card_about_to_expire': 1},
#  3: {'card_payment_wrong_exchange_rate': 33,
#   'wrong_exchange_rate_for_cash_withdrawal': 28,
#   'cancel_transfer': 1,
#   'wrong_amount_of_cash_received': 1,
#   'card_payment_not_recognised': 1,
#   'direct_debit_payment_not_recognised': 1,
#   'cash_withdrawal_charge': 1},
#  4: {'verify_top_up': 28,
#   'card_arrival': 3,
#   'why_verify_identity': 3,
#   'automatic_top_up': 1,
#   'pending_top_up': 1,
#   'receiving_money': 1,
#   'activate_my_card': 1,
#   'verify_my_identity': 1},
#  5: {'top_up_limits': 31,
#   'automatic_top_up': 14,
#   'age_limit': 2,
#   'verify_top_up': 1,
#   'top_up_failed': 1},
#  6: {'top_up_failed': 21,
#   'top_up_reverted': 20,
#   'pending_top_up': 11,
#   'topping_up_by_card': 2},
#  7: {'verify_source_of_funds': 38,
#   'card_payment_wrong_exchange_rate': 1,
#   'transfer_not_received_by_recipient': 1,
#   'declined_cash_withdrawal': 1},
#  8: {'verify_my_identity': 26,
#   'why_verify_identity': 14,
#   'unable_to_verify_identity': 9},
#  9: {'unable_to_verify_identity': 16,
#   'why_verify_identity': 5,
#   'verify_my_identity': 1},
#  10: {'visa_or_mastercard': 33, 'country_support': 19, 'change_pin': 1},
#  11: {'top_up_by_card_charge': 40,
#   'receiving_money': 38,
#   'top_up_by_cash_or_cheque': 37,
#   'exchange_charge': 37,
#   'getting_virtual_card': 35,
#   'fiat_currency_support': 35,
#   'atm_support': 35,
#   'exchange_rate': 34,
#   'supported_cards_and_currencies': 34,
#   'card_acceptance': 34,
#   'top_up_by_bank_transfer_charge': 32,
#   'order_physical_card': 31,
#   'exchange_via_app': 29,
#   'apple_pay_or_google_pay': 29,
#   'getting_spare_card': 27,
#   'change_pin': 27,
#   'card_linking': 27,
#   'transfer_into_account': 24,
#   'get_physical_card': 24,
#   'pin_blocked': 23,
#   'edit_personal_details': 19,
#   'topping_up_by_card': 19,
#   'country_support': 17,
#   'contactless_not_working': 15,
#   'activate_my_card': 14,
#   'automatic_top_up': 12,
#   'card_payment_fee_charged': 11,
#   'cancel_transfer': 10,
#   'passcode_forgotten': 9,
#   'compromised_card': 7,
#   'get_disposable_virtual_card': 6,
#   'top_up_limits': 6,
#   'terminate_account': 5,
#   'card_delivery_estimate': 5,
#   'lost_or_stolen_card': 5,
#   'transfer_fee_charged': 5,
#   'visa_or_mastercard': 5,
#   'card_not_working': 5,
#   'request_refund': 3,
#   'cash_withdrawal_charge': 3,
#   'card_swallowed': 3,
#   'disposable_card_limits': 3,
#   'wrong_exchange_rate_for_cash_withdrawal': 3,
#   'virtual_card_not_working': 3,
#   'card_about_to_expire': 2,
#   'age_limit': 2,
#   'extra_charge_on_statement': 2,
#   'failed_transfer': 2,
#   'balance_not_updated_after_cheque_or_cash_deposit': 2,
#   'beneficiary_not_allowed': 2,
#   'card_arrival': 2,
#   'top_up_reverted': 1,
#   'pending_card_payment': 1,
#   'reverted_card_payment?': 1,
#   'transfer_timing': 1,
#   'declined_card_payment': 1,
#   'declined_transfer': 1,
#   'lost_or_stolen_phone': 1},
#  12: {'terminate_account': 31,
#   'activate_my_card': 2,
#   'card_linking': 1,
#   'top_up_by_bank_transfer_charge': 1,
#   'compromised_card': 1},
#  13: {'card_not_working': 15,
#   'passcode_forgotten': 13,
#   'unable_to_verify_identity': 6,
#   'get_physical_card': 5,
#   'virtual_card_not_working': 5,
#   'lost_or_stolen_phone': 3,
#   'lost_or_stolen_card': 2,
#   'contactless_not_working': 2,
#   'automatic_top_up': 1,
#   'transfer_not_received_by_recipient': 1,
#   'edit_personal_details': 1,
#   'card_swallowed': 1},
#  14: {'edit_personal_details': 12,
#   'change_pin': 4,
#   'getting_spare_card': 3,
#   'getting_virtual_card': 1,
#   'virtual_card_not_working': 1,
#   'activate_my_card': 1},
#  15: {'card_swallowed': 9,
#   'lost_or_stolen_card': 5,
#   'pin_blocked': 4,
#   'compromised_card': 4,
#   'passcode_forgotten': 4,
#   'card_payment_not_recognised': 2,
#   'lost_or_stolen_phone': 2,
#   'reverted_card_payment?': 2,
#   'virtual_card_not_working': 2,
#   'cash_withdrawal_not_recognised': 2,
#   'card_not_working': 1,
#   'edit_personal_details': 1,
#   'unable_to_verify_identity': 1},
#  16: {'card_about_to_expire': 32},
#  17: {'compromised_card': 14,
#   'card_payment_not_recognised': 4,
#   'direct_debit_payment_not_recognised': 2,
#   'transaction_charged_twice': 1},
#  18: {'pending_cash_withdrawal': 13,
#   'failed_transfer': 12,
#   'extra_charge_on_statement': 11,
#   'reverted_card_payment?': 10,
#   'declined_transfer': 10,
#   'pending_card_payment': 6,
#   'pending_transfer': 6,
#   'transfer_not_received_by_recipient': 5,
#   'Refund_not_showing_up': 3,
#   'beneficiary_not_allowed': 3,
#   'declined_card_payment': 3,
#   'virtual_card_not_working': 2,
#   'cash_withdrawal_charge': 2,
#   'balance_not_updated_after_cheque_or_cash_deposit': 2,
#   'declined_cash_withdrawal': 1,
#   'transfer_fee_charged': 1,
#   'pin_blocked': 1,
#   'cash_withdrawal_not_recognised': 1,
#   'card_arrival': 1},
#  19: {'transfer_fee_charged': 13,
#   'card_payment_fee_charged': 11,
#   'cash_withdrawal_charge': 10,
#   'transaction_charged_twice': 5,
#   'extra_charge_on_statement': 2,
#   'wrong_amount_of_cash_received': 2,
#   'direct_debit_payment_not_recognised': 1,
#   'declined_cash_withdrawal': 1,
#   'pending_card_payment': 1,
#   'beneficiary_not_allowed': 1},
#  20: {'pending_top_up': 16,
#   'failed_transfer': 12,
#   'transaction_charged_twice': 12,
#   'declined_transfer': 12,
#   'declined_card_payment': 11,
#   'declined_cash_withdrawal': 10,
#   'pending_cash_withdrawal': 10,
#   'pending_transfer': 10,
#   'Refund_not_showing_up': 10,
#   'pending_card_payment': 9,
#   'balance_not_updated_after_cheque_or_cash_deposit': 9,
#   'cancel_transfer': 8,
#   'request_refund': 8,
#   'beneficiary_not_allowed': 8,
#   'cash_withdrawal_charge': 8,
#   'cash_withdrawal_not_recognised': 8,
#   'transfer_fee_charged': 7,
#   'direct_debit_payment_not_recognised': 7,
#   'balance_not_updated_after_bank_transfer': 7,
#   'transfer_not_received_by_recipient': 6,
#   'reverted_card_payment?': 6,
#   'compromised_card': 6,
#   'top_up_reverted': 5,
#   'wrong_exchange_rate_for_cash_withdrawal': 5,
#   'card_payment_not_recognised': 5,
#   'extra_charge_on_statement': 5,
#   'lost_or_stolen_card': 5,
#   'card_not_working': 4,
#   'card_swallowed': 4,
#   'wrong_amount_of_cash_received': 4,
#   'top_up_failed': 3,
#   'card_payment_fee_charged': 3,
#   'contactless_not_working': 3,
#   'terminate_account': 2,
#   'virtual_card_not_working': 2,
#   'getting_virtual_card': 2,
#   'pin_blocked': 2,
#   'transfer_into_account': 1,
#   'top_up_by_cash_or_cheque': 1,
#   'card_arrival': 1,
#   'verify_source_of_funds': 1,
#   'lost_or_stolen_phone': 1,
#   'card_linking': 1,
#   'topping_up_by_card': 1,
#   'supported_cards_and_currencies': 1,
#   'automatic_top_up': 1,
#   'card_delivery_estimate': 1,
#   'fiat_currency_support': 1,
#   'card_payment_wrong_exchange_rate': 1,
#   'apple_pay_or_google_pay': 1},
#  21: {'card_payment_fee_charged': 6,
#   'cash_withdrawal_charge': 6,
#   'transaction_charged_twice': 3,
#   'transfer_fee_charged': 3,
#   'wrong_amount_of_cash_received': 1},
#  22: {'wrong_amount_of_cash_received': 12,
#   'declined_cash_withdrawal': 6,
#   'balance_not_updated_after_bank_transfer': 1},
#  23: {'direct_debit_payment_not_recognised': 17,
#   'balance_not_updated_after_cheque_or_cash_deposit': 13,
#   'balance_not_updated_after_bank_transfer': 13,
#   'cash_withdrawal_not_recognised': 11,
#   'card_payment_not_recognised': 7,
#   'Refund_not_showing_up': 6,
#   'transfer_not_received_by_recipient': 6,
#   'reverted_card_payment?': 5,
#   'cancel_transfer': 4,
#   'extra_charge_on_statement': 4,
#   'pending_cash_withdrawal': 3,
#   'pending_card_payment': 3,
#   'transaction_charged_twice': 2,
#   'failed_transfer': 2,
#   'card_arrival': 2,
#   'pending_transfer': 2,
#   'card_swallowed': 1,
#   'declined_card_payment': 1,
#   'beneficiary_not_allowed': 1,
#   'declined_cash_withdrawal': 1,
#   'virtual_card_not_working': 1,
#   'compromised_card': 1,
#   'contactless_not_working': 1,
#   'cash_withdrawal_charge': 1}}

# %%
tokenizer = BertTokenizer.from_pretrained('philschmid/BERT-Banking77')
model = BertModel.from_pretrained('philschmid/BERT-Banking77')
# Out:
# tokenizer_config.json:   0%|          | 0.00/313 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/5.95k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
def get_sentence_embeddings(sentence):
    inputs = tokenizer(sentence, return_tensors="pt", truncation=True, max_length=512)
    outputs = model(**inputs)
    embeddings = outputs.last_hidden_state.mean(dim=1).squeeze().detach().numpy()
    return embeddings

# Apply the function to each utterance
test['BERT77_embeddings'] = test['text'].apply(get_sentence_embeddings)
test
# Out:
#                                                    text         category  \
# 0                              How do I locate my card?     card_arrival
# 1     I still have not received my new card, I order...     card_arrival
# 2     I ordered a card but it has not arrived. Help ...     card_arrival
# 3      Is there a way to know when my card will arrive?     card_arrival
# 4                          My card has not arrived yet.     card_arrival
# ...                                                 ...              ...
# 3075      If i'm not in the UK, can I still get a card?  country_support
# 3076                 How many countries do you support?  country_support
# 3077              What countries do you do business in?  country_support
# 3078             What are the countries you operate in.  country_support
# 3079         Can the card be mailed and used in Europe?  country_support
#
#                                         BERT_embeddings  topic  \
# 0     [0.11946714, 0.0462514, 0.07216076, -0.0717430...     11
# 1     [0.1455653, -0.17301682, 0.396418, 0.20625193,...     -1
# 2     [-0.050330862, -0.2557014, 0.44595417, -0.0304...     -1
# 3     [-0.044740878, -0.3670077, 0.41925043, 0.03467...     -1
# 4     [0.3028919, -0.22428086, 0.10192727, -0.203572...     -1
# ...                                                 ...    ...
# 3075  [0.49874625, -0.046890993, 0.43037665, -0.3773...     10
# 3076  [0.4169197, -0.19576609, 0.10278029, -0.101284...     11
# 3077  [0.43335438, -0.14970121, -0.07299802, -0.2744...     11
# 3078  [0.26136342, -0.20304756, -0.15264143, -0.1744...     -1
# 3079  [0.21379073, -0.5117322, 0.2260205, 0.19019113...     -1
#
#                                       BERT77_embeddings
# 0     [0.42865202, -0.43469578, 0.3052942, 0.2347375...
# 1     [0.16829188, 0.09822858, 1.3819345, -0.1845505...
# 2     [0.12018974, -0.12311054, 1.4518343, 0.2730053...
# 3     [-0.15183571, 0.082956925, 1.4436911, 0.078706...
# 4     [0.24080856, 0.40944988, 1.2567027, -0.2404651...
# ...                                                 ...
# 3075  [0.27429864, -0.82551634, 0.25383866, 0.810523...
# 3076  [0.3326514, -0.5459342, 0.062237754, 0.7839224...
# 3077  [0.4262836, -0.46747416, 0.20949411, 0.7919105...
# 3078  [0.41575032, -0.5905341, 0.29422665, 0.8811767...
# 3079  [0.4515565, -0.6814845, 0.13226277, 0.93591243...
#
# [3080 rows x 5 columns]

# %%
bert77_embeddings = np.vstack(test['BERT77_embeddings'].to_numpy())

umap_embeddings_77 = umap.UMAP(n_neighbors=10, n_components=5, metric='cosine').fit_transform(bert77_embeddings)

# %%
hdbscan = HDBSCAN(min_cluster_size=18)
test["topic77"] = hdbscan.fit_predict(umap_embeddings_77)
test
# Out:
#                                                    text         category  \
# 0                              How do I locate my card?     card_arrival
# 1     I still have not received my new card, I order...     card_arrival
# 2     I ordered a card but it has not arrived. Help ...     card_arrival
# 3      Is there a way to know when my card will arrive?     card_arrival
# 4                          My card has not arrived yet.     card_arrival
# ...                                                 ...              ...
# 3075      If i'm not in the UK, can I still get a card?  country_support
# 3076                 How many countries do you support?  country_support
# 3077              What countries do you do business in?  country_support
# 3078             What are the countries you operate in.  country_support
# 3079         Can the card be mailed and used in Europe?  country_support
#
#                                         BERT_embeddings  topic  \
# 0     [0.11946714, 0.0462514, 0.07216076, -0.0717430...     11
# 1     [0.1455653, -0.17301682, 0.396418, 0.20625193,...     -1
# 2     [-0.050330862, -0.2557014, 0.44595417, -0.0304...     -1
# 3     [-0.044740878, -0.3670077, 0.41925043, 0.03467...     -1
# 4     [0.3028919, -0.22428086, 0.10192727, -0.203572...     -1
# ...                                                 ...    ...
# 3075  [0.49874625, -0.046890993, 0.43037665, -0.3773...     10
# 3076  [0.4169197, -0.19576609, 0.10278029, -0.101284...     11
# 3077  [0.43335438, -0.14970121, -0.07299802, -0.2744...     11
# 3078  [0.26136342, -0.20304756, -0.15264143, -0.1744...     -1
# 3079  [0.21379073, -0.5117322, 0.2260205, 0.19019113...     -1
#
#                                       BERT77_embeddings  topic77
# 0     [0.42865202, -0.43469578, 0.3052942, 0.2347375...       49
# 1     [0.16829188, 0.09822858, 1.3819345, -0.1845505...       48
# 2     [0.12018974, -0.12311054, 1.4518343, 0.2730053...       48
# 3     [-0.15183571, 0.082956925, 1.4436911, 0.078706...        1
# 4     [0.24080856, 0.40944988, 1.2567027, -0.2404651...       48
# ...                                                 ...      ...
# 3075  [0.27429864, -0.82551634, 0.25383866, 0.810523...       67
# 3076  [0.3326514, -0.5459342, 0.062237754, 0.7839224...       67
# 3077  [0.4262836, -0.46747416, 0.20949411, 0.7919105...       67
# 3078  [0.41575032, -0.5905341, 0.29422665, 0.8811767...       67
# 3079  [0.4515565, -0.6814845, 0.13226277, 0.93591243...       67
#
# [3080 rows x 6 columns]

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x=umap_embeddings_77[:, 0], y=umap_embeddings_77[:, 1], hue=test["topic77"], legend='full', alpha=0.8, palette=custom_palette)
plt.title('HDBSCAN Clustering')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.legend()
plt.show()

# %%
cluster_info_77 = {}
for i in np.unique(hdbscan.labels_):
  rah = test[test["topic77"]== i]
  value_counts = rah["category"].value_counts()

  category_info = {}
  for index, count in value_counts.items():
    category_info[index] = count

  cluster_info[i] = category_info

cluster_info
# Out:
# {-1: {'compromised_card': 3,
#   'why_verify_identity': 2,
#   'get_disposable_virtual_card': 2,
#   'automatic_top_up': 1,
#   'top_up_reverted': 1,
#   'card_payment_not_recognised': 1,
#   'disposable_card_limits': 1,
#   'getting_spare_card': 1,
#   'virtual_card_not_working': 1},
#  0: {'pending_card_payment': 37,
#   'fiat_currency_support': 1,
#   'pending_transfer': 1},
#  1: {'card_delivery_estimate': 35,
#   'card_arrival': 4,
#   'pending_card_payment': 1},
#  2: {'receiving_money': 38, 'exchange_via_app': 1, 'declined_transfer': 1},
#  3: {'verify_top_up': 40},
#  4: {'age_limit': 40},
#  5: {'exchange_via_app': 38,
#   'fiat_currency_support': 3,
#   'exchange_rate': 1,
#   'exchange_charge': 1},
#  6: {'fiat_currency_support': 35,
#   'supported_cards_and_currencies': 2,
#   'card_delivery_estimate': 1,
#   'exchange_via_app': 1,
#   'receiving_money': 1},
#  7: {'exchange_rate': 39,
#   'exchange_charge': 2,
#   'card_payment_wrong_exchange_rate': 1,
#   'wrong_exchange_rate_for_cash_withdrawal': 1},
#  8: {'edit_personal_details': 40, 'cancel_transfer': 1},
#  9: {'wrong_amount_of_cash_received': 36},
#  10: {'transaction_charged_twice': 40,
#   'top_up_reverted': 1,
#   'pending_card_payment': 1},
#  11: {'declined_transfer': 29},
#  12: {'wrong_exchange_rate_for_cash_withdrawal': 33,
#   'automatic_top_up': 1,
#   'cash_withdrawal_charge': 1},
#  13: {'extra_charge_on_statement': 38, 'transfer_fee_charged': 1},
#  14: {'card_payment_fee_charged': 39,
#   'extra_charge_on_statement': 2,
#   'card_payment_wrong_exchange_rate': 1,
#   'direct_debit_payment_not_recognised': 1,
#   'transfer_fee_charged': 1,
#   'order_physical_card': 1,
#   'cash_withdrawal_charge': 1},
#  15: {'Refund_not_showing_up': 40,
#   'reverted_card_payment?': 2,
#   'request_refund': 1},
#  16: {'card_payment_wrong_exchange_rate': 38,
#   'wrong_exchange_rate_for_cash_withdrawal': 4,
#   'cancel_transfer': 1},
#  17: {'pin_blocked': 33, 'card_not_working': 1},
#  18: {'lost_or_stolen_phone': 39},
#  19: {'visa_or_mastercard': 37},
#  20: {'atm_support': 39, 'top_up_by_cash_or_cheque': 2},
#  21: {'cash_withdrawal_charge': 38,
#   'wrong_exchange_rate_for_cash_withdrawal': 1},
#  22: {'reverted_card_payment?': 34},
#  23: {'get_physical_card': 39, 'pin_blocked': 1},
#  24: {'change_pin': 40, 'pin_blocked': 4, 'get_physical_card': 1},
#  25: {'exchange_charge': 37,
#   'transfer_fee_charged': 1,
#   'wrong_exchange_rate_for_cash_withdrawal': 1},
#  26: {'transfer_fee_charged': 37, 'top_up_by_bank_transfer_charge': 2},
#  27: {'top_up_by_bank_transfer_charge': 36},
#  28: {'failed_transfer': 38,
#   'beneficiary_not_allowed': 4,
#   'declined_transfer': 2,
#   'pending_transfer': 2,
#   'transfer_not_received_by_recipient': 1,
#   'transfer_into_account': 1,
#   'balance_not_updated_after_bank_transfer': 1},
#  29: {'top_up_by_card_charge': 39,
#   'top_up_by_bank_transfer_charge': 1,
#   'top_up_limits': 1},
#  30: {'verify_source_of_funds': 40},
#  31: {'unable_to_verify_identity': 37, 'why_verify_identity': 1},
#  32: {'card_not_working': 39,
#   'virtual_card_not_working': 2,
#   'pin_blocked': 1,
#   'contactless_not_working': 1},
#  33: {'declined_card_payment': 39,
#   'declined_transfer': 6,
#   'reverted_card_payment?': 4,
#   'top_up_failed': 2,
#   'contactless_not_working': 1,
#   'pending_card_payment': 1},
#  34: {'transfer_not_received_by_recipient': 36,
#   'balance_not_updated_after_cheque_or_cash_deposit': 1,
#   'topping_up_by_card': 1,
#   'balance_not_updated_after_bank_transfer': 1},
#  35: {'cancel_transfer': 38, 'beneficiary_not_allowed': 1},
#  36: {'beneficiary_not_allowed': 35,
#   'top_up_reverted': 1,
#   'declined_transfer': 1,
#   'failed_transfer': 1},
#  37: {'pending_top_up': 38,
#   'topping_up_by_card': 3,
#   'automatic_top_up': 1,
#   'top_up_reverted': 1},
#  38: {'request_refund': 39},
#  39: {'cash_withdrawal_not_recognised': 38,
#   'direct_debit_payment_not_recognised': 2,
#   'lost_or_stolen_card': 1,
#   'wrong_amount_of_cash_received': 1},
#  40: {'balance_not_updated_after_bank_transfer': 33,
#   'transfer_not_received_by_recipient': 2,
#   'pending_transfer': 2,
#   'transfer_timing': 2,
#   'balance_not_updated_after_cheque_or_cash_deposit': 1},
#  41: {'card_swallowed': 36},
#  42: {'pending_cash_withdrawal': 39},
#  43: {'automatic_top_up': 37},
#  44: {'top_up_limits': 39, 'topping_up_by_card': 1},
#  45: {'terminate_account': 40, 'pin_blocked': 1},
#  46: {'verify_my_identity': 39,
#   'why_verify_identity': 3,
#   'unable_to_verify_identity': 2,
#   'lost_or_stolen_card': 1},
#  47: {'why_verify_identity': 34, 'verify_my_identity': 1},
#  48: {'card_arrival': 33, 'card_delivery_estimate': 4},
#  49: {'lost_or_stolen_card': 38,
#   'card_arrival': 2,
#   'card_linking': 1,
#   'lost_or_stolen_phone': 1,
#   'cash_withdrawal_not_recognised': 1,
#   'activate_my_card': 1},
#  50: {'activate_my_card': 39},
#  51: {'disposable_card_limits': 34, 'get_disposable_virtual_card': 1},
#  52: {'passcode_forgotten': 40},
#  53: {'getting_spare_card': 39,
#   'disposable_card_limits': 2,
#   'visa_or_mastercard': 1},
#  54: {'declined_cash_withdrawal': 40,
#   'wrong_amount_of_cash_received': 3,
#   'card_swallowed': 3,
#   'pending_cash_withdrawal': 1,
#   'top_up_reverted': 1,
#   'balance_not_updated_after_cheque_or_cash_deposit': 1,
#   'atm_support': 1},
#  55: {'supported_cards_and_currencies': 38, 'visa_or_mastercard': 1},
#  56: {'topping_up_by_card': 32,
#   'transfer_into_account': 4,
#   'top_up_by_cash_or_cheque': 2,
#   'top_up_by_card_charge': 1},
#  57: {'transfer_into_account': 35,
#   'topping_up_by_card': 1,
#   'receiving_money': 1},
#  58: {'top_up_failed': 35,
#   'top_up_reverted': 2,
#   'pending_top_up': 1,
#   'declined_card_payment': 1},
#  59: {'top_up_reverted': 33,
#   'top_up_failed': 3,
#   'pending_top_up': 1,
#   'topping_up_by_card': 1},
#  60: {'direct_debit_payment_not_recognised': 32,
#   'card_payment_fee_charged': 1},
#  61: {'pending_transfer': 35,
#   'balance_not_updated_after_bank_transfer': 3,
#   'transfer_timing': 2,
#   'transfer_not_received_by_recipient': 1},
#  62: {'transfer_timing': 36, 'balance_not_updated_after_bank_transfer': 2},
#  63: {'order_physical_card': 38,
#   'card_arrival': 1,
#   'getting_virtual_card': 1,
#   'compromised_card': 1,
#   'card_swallowed': 1,
#   'get_disposable_virtual_card': 1},
#  64: {'balance_not_updated_after_cheque_or_cash_deposit': 35},
#  65: {'top_up_by_cash_or_cheque': 36,
#   'balance_not_updated_after_cheque_or_cash_deposit': 2,
#   'top_up_by_bank_transfer_charge': 1,
#   'declined_transfer': 1},
#  66: {'card_acceptance': 37, 'visa_or_mastercard': 1, 'failed_transfer': 1},
#  67: {'country_support': 40, 'card_acceptance': 3, 'fiat_currency_support': 1},
#  68: {'card_linking': 39, 'topping_up_by_card': 1},
#  69: {'apple_pay_or_google_pay': 40},
#  70: {'get_disposable_virtual_card': 33, 'disposable_card_limits': 1},
#  71: {'contactless_not_working': 38},
#  72: {'card_about_to_expire': 40},
#  73: {'virtual_card_not_working': 19, 'disposable_card_limits': 1},
#  74: {'card_payment_not_recognised': 37,
#   'direct_debit_payment_not_recognised': 5,
#   'cash_withdrawal_not_recognised': 1},
#  75: {'compromised_card': 36,
#   'card_payment_not_recognised': 2,
#   'unable_to_verify_identity': 1},
#  76: {'getting_virtual_card': 38,
#   'get_disposable_virtual_card': 3,
#   'disposable_card_limits': 1,
#   'order_physical_card': 1},
#  77: {'virtual_card_not_working': 18, 'getting_virtual_card': 1}}
